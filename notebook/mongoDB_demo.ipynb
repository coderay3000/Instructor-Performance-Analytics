# %%
import pandas as pd
import pymongo

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\ayush\Desktop\ML-OPS\Instructor-Performance-Analytics\notebook

# %%
df=pd.read_csv("instructor_effectiveness_dataset_2000_rows - instructor_effectiveness_dataset_2000_rows.csv.csv")

df.head()
# Out:
#   batch_id instructor_id course_id  completion_rate  avg_score_improvement  \
# 0   B_1861         I_044      C_01         0.300000              14.225955
# 1   B_0354         I_119      C_06         0.657220              22.871110
# 2   B_1334         I_050      C_03         0.300000              16.087517
# 3   B_0906         I_024      C_21         0.639507              24.260687
# 4   B_1290         I_001      C_08         0.527302              31.081556
#
#    avg_quiz_score  dropout_rate  avg_watch_time  assignment_submission_rate  \
# 0       73.546528      0.647423        0.774572                    0.790918
# 1       77.312331      0.425098        0.494936                    0.998566
# 2       79.563687      0.700000        0.977901                    0.807298
# 3       99.295316      0.334657        0.846515                    0.544555
# 4       99.393425      0.521099        0.917450                    0.865885
#
# ...

# %%
import os

print(os.listdir())
# Out:
# ['instructor_effectiveness_dataset_2000_rows - instructor_effectiveness_dataset_2000_rows.csv.csv', 'mongoDB_demo.ipynb']

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')
# data

# %%
DB_NAME = "Proj2"
COLLECTION_NAME = "Proj2-Data"
CONNECTION_URL = "mongodb+srv://ayush1337yadav_db_user:<db_password>@cluster0.fsbxxkm.mongodb.net/?appName=Cluster0"

# above, either remove your credentials or delete the mongoDB resource bofore pushing it to github

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
rec = collection.insert_many(data)

# %%
df = pd.DataFrame(list(collection.find()))
df.head()
# Out:
#                         _id batch_id instructor_id course_id  completion_rate  \
# 0  6a59c71c661b337924cf66a2   B_1861         I_044      C_01         0.300000
# 1  6a59c71c661b337924cf66a3   B_0354         I_119      C_06         0.657220
# 2  6a59c71c661b337924cf66a4   B_1334         I_050      C_03         0.300000
# 3  6a59c71c661b337924cf66a5   B_0906         I_024      C_21         0.639507
# 4  6a59c71c661b337924cf66a6   B_1290         I_001      C_08         0.527302
#
#    avg_score_improvement  avg_quiz_score  dropout_rate  avg_watch_time  \
# 0              14.225955       73.546528      0.647423        0.774572
# 1              22.871110       77.312331      0.425098        0.494936
# 2              16.087517       79.563687      0.700000        0.977901
# 3              24.260687       99.295316      0.334657        0.846515
# 4              31.081556       99.393425      0.521099        0.917450
#
# ...
